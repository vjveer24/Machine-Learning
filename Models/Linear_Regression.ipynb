# %%
#Linear Regression (criessssss in excitement!!!!!)
#Supervised Regression Machine Learning Algorithm
#Types- Simple,Multiple,Polynomial

# %%
#Simple Linear Regression-(one input)
#find a "best-fit line" that minimizes errors between predicted and actual values. The line is represented by the equation, 
# y=mx+c where m is the slope (weight) and c is the intercept (bias). The slope m indicates the impact of the input on the output, 
# while c accounts for the base value.
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
